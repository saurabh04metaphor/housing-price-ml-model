# %%
import pandas as pd

# %%
path = "1. Regression - Module - (Housing Prices).csv"

# %%
data = pd.read_csv(path)

# %%
Raw_Housing_Data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
Raw_Housing_Data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %% [markdown]
# # Descriptives of the Dataset -Part-1

# %%
Raw_Housing_Data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
Raw_Housing_Data['Sale Price'].std()
# Out:
# 367388.99446065375

# %%
Raw_Housing_Data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
import numpy as np

# %%
Raw_Housing_Data['Sale Price'].std()-np.std(Raw_Housing_Data['Sale Price'],ddof=1)
# Out:
# 0.0

# %%
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_CopyMode',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__deprecated_attrs__',
#  '__dir__',
#  '__doc__',
# ...

# %% [markdown]
# # Plotting Graphs_1

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Raw_Housing_Data['Sale Price'])

# %%
plt.plot(Raw_Housing_Data['Sale Price'], color = 'green')
plt.xlabel("Record Number")
plt.ylabel("Sale Price")
plt.title("My First Graph")
plt.show()

# %%
plt.plot(Raw_Housing_Data['Sale Price'],marker = 'o',markerfacecolor = 'Blue',markersize=5,color='green',linewidth=5,linestyle='dashed')

# %%
Raw_Housing_Data.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values = (30,1701,14031,5679,172)
labels = ('Bad','Excellent','Fair','Good','Okay')
plt.pie(values, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x26f37a02a90>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %%
plt.bar(labels,values,color='Blue')
# Out:
# <BarContainer object of 5 artists>

# %%
Raw_Housing_Data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
data['condition_sale'] = 0
for i in data['Condition of the House'].unique():
data['condition_sale'][data['Condition of the House'] == str(i)] = data['Sale Price'][data['Condition of the House'] == str(i)].mean()
# Out:
# C:\Users\Saurabh Bharti\AppData\Local\Temp\ipykernel_7680\359243957.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['condition_sale'][data['Condition of the House'] == str(i)] = data['Sale Price'][data['Condition of the House'] == str(i)].mean()

# %%
data['condition_sale'] = 0

# %%
data['condition_sale']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 21608    0
# 21609    0
# 21610    0
# 21611    0
# 21612    0
# Name: condition_sale, Length: 21613, dtype: int64

# %%
#Initialising a new column
data['condition_sale'] = 0

# Calculating mean based on the condition of the House
for i in data['Condition of the House'].unique():
  data['condition_sale'][data['Condition of the House'] == str(i)] = data['Sale Price'][data['Condition of the House'] == str(i)].mean()

data['condition_sale'].unique()
# Out:
# C:\Users\Saurabh Bharti\AppData\Local\Temp\ipykernel_7680\3394850897.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['condition_sale'][data['Condition of the House'] == str(i)] = data['Sale Price'][data['Condition of the House'] == str(i)].mean()
# array([542130.61120616, 612577.74250441, 521277.5105671 , 334431.66666667,
#        327316.21511628])

# %%
data.groupby('Condition of the House')['Sale Price'].mean()
# Out:
# Condition of the House
# Bad          334431.666667
# Excellent    612577.742504
# Fair         542130.611206
# Good         521277.510567
# Okay         327316.215116
# Name: Sale Price, dtype: float64

# %%
#Plotting the mean sales based on the Condition of the House
import matplotlib.pyplot as plt
plt.figure( dpi = 100 )
plt.bar(data['Condition of the House'].unique(), data['condition_sale'].unique())
plt.xlabel("Condition of the House")
plt.ylabel("Mean Sale Price")
plt.show()

# %%
import time
data['zip_condition_sale'] = 0

C = 'Condition of the House'
Z = 'Zipcode'

tick = time.time()
for i in data[C].unique():
    for j in data[Z].unique():
        data['zip_condition_sale'][(data[C] == str(i)) & (data[Z] == j)] = data['Sale Price'][(data[C] == str(i)) & (data[Z] == j)].mean()
tock = time.time()
time1 = tock - tick
print(time1)
len(data['zip_condition_sale'].unique())
# Out:
# C:\Users\Saurabh Bharti\AppData\Local\Temp\ipykernel_7680\3733514967.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['zip_condition_sale'][(data[C] == str(i)) & (data[Z] == j)] = data['Sale Price'][(data[C] == str(i)) & (data[Z] == j)].mean()
# 1.526984453201294
# 281

# %%
zip_condition_sale = data.groupby(['Condition of the House', 'Zipcode'])['Sale Price'].mean()

# %%
zip_condition_sale.to_csv('file.csv')

# %%
data[['Condition of the House','Zipcode','Sale Price']]
# Out:
#       Condition of the House  Zipcode  Sale Price
# 0                       Fair  98178.0    221900.0
# 1                       Fair  98125.0    538000.0
# 2                       Fair  98028.0    180000.0
# 3                  Excellent  98136.0    604000.0
# 4                       Fair  98074.0    510000.0
# ...                      ...      ...         ...
# 21608                   Fair  98103.0    360000.0
# 21609                   Fair  98146.0    400000.0
# 21610                   Fair  98144.0    402101.0
# 21611                   Fair  98027.0    400000.0
# 21612                   Fair  98144.0    325000.0
#
# [21613 rows x 3 columns]

# %%
len(data['Zipcode'].unique())
# Out:
# 71

# %%
import numpy as np
zip_condition_sale2 = pd.pivot_table(data, index=["Zipcode"], columns=["Condition of the House"], values=["Sale Price"],aggfunc=np.mean,)
zip_condition_sale2
# Out:
#                        Sale Price                                            \
# Condition of the House        Bad     Excellent          Fair          Good
# Zipcode
# 98001.0                       NaN  2.425433e+05  2.927207e+05  2.527446e+05
# 98002.0                       NaN  2.216411e+05  2.588868e+05  2.192858e+05
# 98003.0                       NaN  3.706800e+05  2.992801e+05  2.809591e+05
# 98004.0                 1500000.0  1.236365e+06  1.527265e+06  1.145915e+06
# 98005.0                       NaN  8.319500e+05  8.668012e+05  7.669397e+05
# ...                           ...           ...           ...           ...
# 98177.0                       NaN  8.966313e+05  6.496812e+05  6.665755e+05
# 98178.0                       NaN  2.975217e+05  3.094105e+05  3.308419e+05
# 98188.0                       NaN  2.853636e+05  2.900059e+05  2.867413e+05
# 98198.0                       NaN  3.215235e+05  2.941619e+05  3.154305e+05
# ...

# %%
import pandas as pd
import numpy as np

# %%
data['plot length'] = data['Flat Area (in Sqft)']**0.5

# %%
data['plot length']
# Out:
# 0        34.351128
# 1        50.695167
# 2        27.748874
# 3        44.271887
# 4        40.987803
#            ...
# 21608    39.115214
# 21609    48.062459
# 21610    31.937439
# 21611    40.000000
# 21612    31.937439
# Name: plot length, Length: 21613, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data['total area'] = data['Flat Area (in Sqft)'] + data['Lot Area (in Sqft)']
data['total area']
# Out:
# 0         6830.0
# 1         9812.0
# 2        10770.0
# 3         6960.0
# 4         9760.0
#           ...
# 21608     2661.0
# 21609     8123.0
# 21610     2370.0
# 21611     3988.0
# 21612     2096.0
# Name: total area, Length: 21613, dtype: float64

# %%
data['Condition of the House'] = data['Condition of the House'].map({'Good':'1',
                                                                     'Excellent':'3',
                                                                     'Bad':'0',
                                                                     'Fair': '1',
                                                                     'Okay': '0'})
data['Condition of the House'].unique()
# Out:
# array(['1', '3', '0'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.groupby('Condition of the House')['Condition of the House'].count()
# Out:
# Condition of the House
# 0      202
# 1    19710
# 3     1701
# Name: Condition of the House, dtype: int64

# %%
data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
year = []
for i in range(len(data['Date House was Sold'])):
  k = data['Date House was Sold'][i].split()[-1]
  year.append(k)

data['year_sold'] = year
data['year_sold'].head()
# Out:
# 0    2017
# 1    2017
# 2    2016
# 3    2017
# 4    2016
# Name: year_sold, dtype: object

# %%
def year(value):
    return value.split()[-1]

data['year_sold'] = data['Date House was Sold'].map(year)
data['year_sold'].head()
# Out:
# 0    2017
# 1    2017
# 2    2016
# 3    2017
# 4    2016
# Name: year_sold, dtype: object

# %%
data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data['Sale Price'].head(10)
# Out:
# 0     221900.0
# 1     538000.0
# 2     180000.0
# 3     604000.0
# 4     510000.0
# 5    1230000.0
# 6     257500.0
# 7     291850.0
# 8     229500.0
# 9     323000.0
# Name: Sale Price, dtype: float64

# %%
count = 0
for i in data['Sale Price'].head(10):
    if i > 1129575:
        print(i)
        count = count+1
# Out:
# 1230000.0

# %% [markdown]
# # Identifying the Outliers

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=data['ID'], y=data['Sale Price'])

# %%
import seaborn as sns

# %%
sns.boxplot(x = data['Sale Price'])
# Out:
# <Axes: xlabel='Sale Price'>

# %%
q1 = data['Sale Price'].quantile(.25)
q3 = data['Sale Price'].quantile(.75)

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 323050.0

# %%
upper_limit = q3 + 1.5*iqr
lower_limit = q1 - 1.5*iqr
upper_limit,lower_limit
# Out:
# (1129575.0, -162625.0)

# %%
def limit_imputer(value):
    if value > upper_limit:
        return upper_limit
    if value < lower_limit:
        return lower_limit
    else:
        return value

# %%
data['Sale Price'] = data['Sale Price'].apply(limit_imputer)

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
data.to_csv('data2.csv',index=False)

# %%
data.dropna(inplace = True, axis = 0, subset = ['Sale Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data['No of Times Visited'].describe()
# Out:
# count      2124
# unique        4
# top       Twice
# freq        963
# Name: No of Times Visited, dtype: object

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(data['Sale Price'], bins = 10, color = 'green')
plt.xlabel("Intervals")
plt.ylabel("Selling Price")
plt.title("Histogram of Selling Price")
plt.show()

# %% [markdown]
# #Handling Independent Numerical Variables

# %%
import pandas as pd
data = pd.read_csv('data2.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
numerical_colns = ['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)',
                  'Area of the House from Basement (in Sqft)','Latitude',
                   'Longitude','Living Area after Renovation (in Sqft)']

# %%
data['No of Times Visited'].unique()
# Out:
# array([nan, 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy= 'median')
data[numerical_colns] = imputer.fit_transform(data[numerical_colns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data['Zipcode'].shape
# Out:
# (21609,)

# %%
coln = data['Zipcode'].values.reshape(-1,1)
coln
# Out:
# array([[98178.],
#        [98125.],
#        [98028.],
#        ...,
#        [98144.],
#        [98027.],
#        [98144.]])

# %%
#colns = []
import numpy as np
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy= 'most_frequent')
data['Zipcode'] = imputer.fit_transform(coln)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data.to_csv('data3.csv',index=False)

# %%
data['Zipcode'] = data['Zipcode'].astype(object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
data['No of Times Visited'].fillna('None',inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21609 entries, 0 to 21608
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
data['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping = {
    'None': '0',
    'Once': '1',
    'Twice': '2',
    'Thrice': '3',
    'Four': '4'
}
data['No of Times Visited'] = data['No of Times Visited'].map(mapping)

# %%
data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
import numpy as np

# %%
data['Ever Renovate'] = np.where(data['Renovated Year'] == 0, 'No', 'Yes')

# %%
data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21604   263000018         14 May 2017    360000.0               3
# 21605  6600060120    15 February 2016    400000.0               4
# 21606  1523300141        14 June 2017    402101.0               2
# 21607   291310100     15 January 2016    400000.0               3
# 21608  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
data['Purchase Year'] = pd.DatetimeIndex(data['Date House was Sold']).year

# %%
data['Years Since Renovation'] = np.where(data['Ever Renovate'] == 'Yes',
                                         abs(data['Purchase Year'] -
                                            data['Renovated Year']),0)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
data.drop(columns = ['Purchase Year','Date House was Sold','Renovated Year'],inplace = True)

# %%
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
data.to_csv('tdata.csv', index = False)

# %% [markdown]
# #Correlation

# %%
tdata = pd.read_csv('tdata.csv')
tdata['Sale Price'].corr(tdata['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420672

# %%
np.corrcoef(tdata['Sale Price'], tdata['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
tdata.drop(columns = ['ID']).corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 tdata.drop(columns = ['ID']).corr()
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
tdata.dtypes
# Out:
# ID                                             int64
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                            int64
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Zipcode                                      float64
# Latitude                                     float64
# Longitude                                    float64
# Living Area after Renovation (in Sqft)       float64
# ...

# %%
non_numeric_column = ['ID','Waterfront View','Condition of the House','Ever Renovate']

# %%
tdata.drop(columns=non_numeric_column)
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21604    360000.0               3             2.50               1530.0
# 21605    400000.0               4             2.50               2310.0
# 21606    402101.0               2             0.75               1020.0
# 21607    400000.0               3             2.50               1600.0
# 21608    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  No of Times Visited  Overall Grade  \
# ...

# %%
tdata = pd.read_csv('tdata.csv')

# %%
non_numeric_column = ['ID','Waterfront View','Condition of the House','Ever Renovate']

# %%
tdata.drop(columns=non_numeric_column).corr()
# Out:
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# No of Times Visited                          0.356114        0.079575
# Overall Grade                                0.680914        0.349223
# Area of the House from Basement (in Sqft)    0.606527        0.477549
# Basement Area (in Sqft)                      0.307513        0.303294
# Age of House (in Years)                     -0.064306       -0.154113
# Zipcode                                     -0.043047       -0.152760
# ...
